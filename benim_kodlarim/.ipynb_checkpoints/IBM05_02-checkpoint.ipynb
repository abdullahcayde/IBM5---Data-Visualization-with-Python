# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from PIL import Image # converting images into arrays

pd.set_option('display.max_columns', None)

mpl.style.use(['ggplot'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('df_can.csv')
df.drop(195, axis=0, inplace=True)
df.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 190  South-Eastern Asia  902  Developing regions  1191  1829  2162  3404
# 191     Northern Africa  902  Developing regions     0     0     0     0
# 192        Western Asia  902  Developing regions     1     2     1     6
# 193      Eastern Africa  902  Developing regions    11    17    11     7
# 194      Eastern Africa  902  Developing regions    72   114   102    44
#
#      1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  \
# ...

# %%
# Recap 01
df.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

df.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)

df['Total'] = df.select_dtypes(include=np.number).sum(axis=1)

df.set_index('Country', inplace=True)

years = list(map(str, np.arange(1980, 2014)))

df.head(1)
# Out:
#             Continent         Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
#
#              1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  \
# Country
# Afghanistan    47    71   340   496   741   828  1076  1028  1378  1170   713
#
#              1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  \
# Country
# Afghanistan   858  1537  2212  2555  1999  2395  3326  4067  3697  3479  2978
#
#              2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# Country
# Afghanistan  3436  3009  2652  2111  1746  1758  2203  2635  2004  58639

# %% [markdown]
# # Line Plots

# %% [markdown]
# # Area Plots

# %%
df.sort_values(['Total'], ascending=False, axis=0).head()
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
years = list(map(str, range(1980,2014)))

df.sort_values(['Total'], ascending=False, axis=0)

df_top5 = df.sort_values(['Total'], ascending=False, axis=0).head()
df_top5 = df_top5[years].transpose()
df_top5.head()
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
#
# Country  Philippines  Pakistan
# 1980            6051       978
# 1981            5921       972
# 1982            5249      1201
# 1983            4562       900
# 1984            3801       668

# %%
df_top5.plot(kind='area',
             stacked= False,
             alpha= 0.35, # 0 - 1 default 0.5
             figsize=(20,10))

plt.title('Immigrattion trend of top 5 countries')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_top5.plot(kind='area',
             stacked= True,
             figsize=(20,10))

plt.title('Immigrattion trend of top 5 countries')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_least5 = df.sort_values(['Total'], ascending=False, axis=0).tail().loc[:, '1980':'2013'].transpose()
ax = df_least5.plot(kind='area',
                    stacked=True,
                     alpha=0.45,
                    figsize=(20,10))
                                                                                               
                                                                                                                                                                            
ax.set_title('Immigration Trend of least 5 Countries')
ax.set_ylabel('Number of Immigrants')
ax.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
df_least5 = df.sort_values(['Total'], ascending=True, axis=0).head().loc[:, '1980':'2013'].transpose()
ax = df_least5.plot(kind='area',
                    stacked= False,
                     alpha=0.45,
                    figsize=(20,10))
                                                                                               
                                                                                                                                                                            
ax.set_title('Immigration Trend of least 5 Countries')
ax.set_ylabel('Number of Immigrants')
ax.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
df.sort_values(['Total'], ascending=True, axis=0).head().loc[:, '1980':'2013'].transpose().head()
# Out:
# Country  Palau  Marshall Islands  Western Sahara  San Marino  New Caledonia
# 1980         0                 0               0           1              0
# 1981         0                 0               0           0              0
# 1982         0                 0               0           0              0
# 1983         0                 0               0           0              0
# 1984         0                 0               0           0              0

# %%
df_least5
# Out:
# Country  Palau  Marshall Islands  Western Sahara  San Marino  New Caledonia
# 1980         0                 0               0           1              0
# 1981         0                 0               0           0              0
# 1982         0                 0               0           0              0
# 1983         0                 0               0           0              0
# 1984         0                 0               0           0              0
# 1985         0                 0               0           0              0
# 1986         0                 0               0           1              0
# 1987         0                 0               0           0              0
# 1988         0                 0               0           0              0
# 1989         0                 0               0           0              0
# 1990         0                 0               0           1              0
# ...

# %%
df.loc[['Pakistan'], :]
# Out:
#          Continent         Region             DevName  1980  1981  1982  1983  \
# Country
# Pakistan      Asia  Southern Asia  Developing regions   978   972  1201   900
#
#           1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  \
# Country
# Pakistan   668   514   691  1072  1334  2261  2470  3079  4071  4777  4666
#
#           1995  1996   1997  1998  1999   2000   2001   2002   2003   2004  \
# Country
# Pakistan  4994  9125  13073  9068  9979  15400  16708  15110  13205  13399
#
#            2005   2006   2007  2008  2009  2010  2011   2012   2013   Total
# Country
# Pakistan  14314  13127  10124  8994  7217  6811  7468  11227  12603  241600

# %% [markdown]
# # Histogram Plot

# %%
df['2013']
# Out:
# Country
# Afghanistan       2004
# Albania            603
# Algeria           4331
# American Samoa       0
# Andorra              1
#                   ...
# Viet Nam          2112
# Western Sahara       0
# Yemen              217
# Zambia              59
# Zimbabwe           407
# Name: 2013, Length: 195, dtype: int64

# %%
count, bin_edges = np.histogram(df['2013'])

df['2013'].plot(kind = 'hist', xticks= bin_edges, figsize=(10,5))

plt.title('Histogram of Immigration from 195 countries in 2013')
plt.ylabel('Number of countries')
plt.xlabel('Numver of Immigrants')

plt.show()

# %%
df['2013'].plot(kind='hist');

# %%
df['2013'].loc[df.index].plot(kind='hist');

# %%
df_dns = df.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
df_dns.head()
# Out:
# Country  Denmark  Norway  Sweden
# 1980         272     116     281
# 1981         293      77     308
# 1982         299     106     222
# 1983         106      51     176
# 1984          93      31     128

# %%
df_dns.plot(kind = 'hist', figsize= (10,6))

plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
# let's get the x-tick values
count, bin_edges = np.histogram(df_dns, 15)

# un-stacked histogram
df_dns.plot(kind ='hist', 
          figsize=(15, 10),
          bins=15,
          alpha=0.6,
          xticks=bin_edges,
          color=['coral', 'darkslateblue', 'mediumseagreen']
         )

plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
# let's get the x-tick values
bin_edges = np.arange(0,330, 10)

# un-stacked histogram
df_dns.plot(kind ='hist', 
          figsize=(15, 10),
          bins=15,
          alpha=0.6,
          xticks=bin_edges,
          yticks=np.arange(0,14, 1),
          color=['coral', 'darkslateblue', 'mediumseagreen']
         )

plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# # Bar Charts

# %%
years = list(map(str, np.arange(1980, 2014)))

df_iceland = df.loc['Iceland', years]

df_iceland.plot(kind ='bar', figsize=(10,5));

plt.title('Icelandic Immigratns to Canada from 1980 to 2013')
plt.ylabel('Year')
plt.xlabel('Numver of Immigrants')
# Out:
# Text(0.5, 0, 'Numver of Immigrants')

# %%
df.loc[:, '2013'].sort_values(ascending=False).head(10).plot(kind='bar', figsize=(10,5));

# %%
df.loc[:, '2012':'Total']
# Out:
#                 2012  2013  Total
# Country
# Afghanistan     2635  2004  58639
# Albania          620   603  15699
# Algeria         3774  4331  69439
# American Samoa     0     0      6
# Andorra            1     1     15
# ...              ...   ...    ...
# Viet Nam        1731  2112  97146
# Western Sahara     0     0      2
# Yemen            174   217   2985
# Zambia            46    59   1677
# Zimbabwe         437   407   8598
#
# [195 rows x 3 columns]

# %%
df['Total'].sort_values( ascending=False, axis=0).head(15)
# Out:
# Country
# India                                                   691904
# China                                                   659962
# United Kingdom of Great Britain and Northern Ireland    551500
# Philippines                                             511391
# Pakistan                                                241600
# United States of America                                241122
# Iran (Islamic Republic of)                              175923
# Sri Lanka                                               148358
# Republic of Korea                                       142581
# Poland                                                  139241
# Lebanon                                                 115359
# France                                                  109091
# Jamaica                                                 106431
# Viet Nam                                                 97146
# Romania                                                  93585
# ...

# %%
df['Total'].sort_values( ascending=True, axis=0).tail(15).plot(kind='barh',
                                                               figsize = (15, 8));

plt.title('Top 15 Countries of Total Immigrants to Canada from 1980 to 2013')
plt.ylabel('Countries')
plt.xlabel('Number of Immigrants')
# Out:
# Text(0.5, 0, 'Number of Immigrants')

# %% [markdown]
# ## Bar Plot Text Annotate

# %%
df_top15 = df['Total'].sort_values( ascending=True, axis=0).tail(15)
df_top15.plot(kind='barh',
              figsize = (15, 8));

plt.title('Top 15 Countries of Total Immigrants to Canada from 1980 to 2013')
plt.ylabel('Countries')
plt.xlabel('Number of Immigrants')

# Annotate arrow
plt.annotate(df.loc['Jamaica' , 'Total'],  # s: str. Will leave it blank for no text
             xy=(120000, 1.8),  # place head of the arrow at point (year 2012 , pop 70)
             verticalalignment= 'bottom',
             horizontalalignment= 'center',
             )

plt.show()

# %%
df_top15 = df['Total'].sort_values( ascending=True, axis=0).tail(15)
df_top15.plot(kind='barh',
            figsize = (15, 8),
            color= 'y');

plt.title('Top 15 Countries of Total Immigrants to Canada from 1980 to 2013')
plt.ylabel('Countries')
plt.xlabel('Number of Immigrants')

# Annotate arrow
plt.annotate(df.loc['Jamaica' , 'Total'],  # s: str. Will leave it blank for no text
             xytext = (180000, 1.8),
             
             xy=(120000, 2),  # place head of the arrow at point (year 2012 , pop 70)
             verticalalignment= 'bottom',
             horizontalalignment= 'center',
             arrowprops= {'facecolor' : 'blue', 'shrink': 0.02}
             
             )

plt.show()

# %%
df_top15 = df['Total'].sort_values( ascending=True, axis=0).tail(15)
df_top15.plot(kind='barh',
            figsize = (15, 8),
            color= 'y');

plt.title('Top 15 Countries of Total Immigrants to Canada from 1980 to 2013')
plt.ylabel('Countries')
plt.xlabel('Number of Immigrants')


# annotate value labels to each country
n =15 
for index, value in enumerate(df_top15): 
    label = format(int(value), ',') # format int with commas
    plt.annotate(f'{index+n}-)  {label}', xy=(value - 60000, index - 0.10), color='blue')
    n = n-2
    
plt.show()

# %% [markdown]
# # Pie Chart

# %%
df_continent = df.groupby('Continent', axis=0).sum()
df_continent.head()
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
#
#                                   1986   1987   1988   1989   1990   1991  \
# Continent
# Africa                            3782   7494   7552   9894  11012  14228
# Asia                             28739  43203  47454  60256  72829  89964
# Europe                           24370  46698  54726  60893  68301  57938
# Latin America and the Caribbean  21179  28471  21924  25060  27942  36827
# Northern America                  7074   7705   6469   6790   5895   6057
#
# ...

# %%
df_continent['Total'].plot(kind= 'pie',
                          figsize = (7,7))
plt.title('Immigration to Canada by continent [1980 - 2013]');

plt.show()

# %%
df.groupby(by='Continent', axis=0, as_index=False)['2013'].sum()
# Out:
#                          Continent    2013
# 0                           Africa   38543
# 1                             Asia  155075
# 2                           Europe   28691
# 3  Latin America and the Caribbean   24950
# 4                 Northern America    8503
# 5                          Oceania    1775

# %%
df.groupby(by='Continent', axis=0, as_index=True)['2013'].sum().plot(kind='pie', 
                                                                     y='2013',
                                                                     x='Continent');

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

df.groupby(by='Continent', axis=0, as_index=True)['2013'].sum().plot(kind='pie', 
                                                                     y='2013',
                                                                     x='Continent',
                                                                     
                                                                    autopct='%1.1f%%');

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.15, 0, 0, 0, 0.15, 0.15] # ratio for each continent with which to offset each wedge.

df_2013 = df.groupby(by='Continent', axis=0, as_index=True)['2013'].sum()
df_2013.plot(kind='pie', 
                y='2013',
                x='Continent',
                                                                    
                figsize= (15,6),
                                                                     
                autopct='%1.1f%%',
                                                                    
                colors=colors_list,
                                                                    
                explode=explode_list,
                
                shadow=True);

# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.1) 

plt.axis('equal') 

# add legend
plt.legend(labels=df_2013.index, loc='upper left') 

plt.show()

# %% [markdown]
# # Box Plot

# %%
df_japan = df.loc[['Japan'], years].transpose()
df_japan.head()
# Out:
# Country  Japan
# 1980       701
# 1981       756
# 1982       598
# 1983       309
# 1984       246

# %%
df.loc[['Japan'], : ]
# Out:
#         Continent        Region            DevName  1980  1981  1982  1983  \
# Country
# Japan        Asia  Eastern Asia  Developed regions   701   756   598   309
#
#          1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  \
# Country
# Japan     246   198   248   422   324   494   379   506   605   907   956
#
#          1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  \
# Country
# Japan     826   994   924   897  1083  1010  1092   806   817   973  1067
#
#          2006  2007  2008  2009  2010  2011  2012  2013  Total
# Country
# Japan    1212  1250  1284  1194  1168  1265  1214   982  27707

# %%
df_japan.plot(kind= 'box')
# Out:
# <AxesSubplot:>

# %%
df_ci = df.loc[['India', 'China'], years].transpose()
df_ci.head()
# Out:
# Country  India  China
# 1980      8880   5123
# 1981      8670   6682
# 1982      8147   3308
# 1983      7338   1863
# 1984      5704   1527

# %%
df_ci.describe()
# Out:
# Country         India         China
# count       34.000000     34.000000
# mean     20350.117647  19410.647059
# std      10007.342579  13568.230790
# min       4211.000000   1527.000000
# 25%      10637.750000   5512.750000
# 50%      20235.000000  19945.000000
# 75%      28699.500000  31568.500000
# max      36210.000000  42584.000000

# %%
df_ci.plot(kind='box');

# %%
df_ci.plot(kind='box',
          vert=False);

plt.title('Box plots of Immigrants from China and India (1980 - 2013)')
plt.ylabel('Number of Immigrants')

plt.show()

# %% [markdown]
# ## *Subplot

# %%
fig = plt.figure()

ax0 = fig.add_subplot(1, 2, 1)
ax1 = fig.add_subplot(1, 2, 2)

# Subplot 1
df_ci.plot(kind='box', color='blue', vert=False, figsize=(20,6), ax=ax0)
ax0.set_title('Box Plots of Immigrants from China and India (1980 - 2013)')
ax0.set_xlabel('Number of Immigrants')
ax0.set_ylabel('Countries')

# Subplot 2
df_ci.plot(kind='line', figsize=(20, 6), ax=ax1)
ax1.set_title ('Line Plots of Immigrants from China and India (1980 - 2013)')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
df_top155 = df.sort_values(['Total'], ascending=False).head(15).transpose()

df_top15 = df.sort_values(['Total'], ascending=False).head(15)
df_top15.head(2)
# Out:
#         Continent         Region             DevName  1980  1981  1982  1983  \
# Country
# India        Asia  Southern Asia  Developing regions  8880  8670  8147  7338
# China        Asia   Eastern Asia  Developing regions  5123  6682  3308  1863
#
#          1984  1985  1986   1987   1988   1989   1990   1991   1992   1993  \
# Country
# India    5704  4211  7150  10189  11522  10343  12041  13734  13673  21496
# China    1527  1816  1960   2643   2758   4323   8076  14255  10846   9817
#
#           1994   1995   1996   1997   1998   1999   2000   2001   2002   2003  \
# Country
# India    18620  18489  23859  22268  17241  18974  28572  31223  31889  27155
# China    13128  14398  19415  20475  21049  30069  35529  36434  31961  36439
#
#           2004   2005   2006   2007   2008   2009   2010   2011   2012   2013  \
# Country
# India    28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
# ...

# %%
df_top155.head(2)
# Out:
# Country            India         China  \
# Continent           Asia          Asia
# Region     Southern Asia  Eastern Asia
#
# Country   United Kingdom of Great Britain and Northern Ireland  \
# Continent                                             Europe
# Region                                       Northern Europe
#
# Country           Philippines       Pakistan United States of America  \
# Continent                Asia           Asia         Northern America
# Region     South-Eastern Asia  Southern Asia         Northern America
#
# Country   Iran (Islamic Republic of)      Sri Lanka Republic of Korea  \
# Continent                       Asia           Asia              Asia
# Region                 Southern Asia  Southern Asia      Eastern Asia
#
# Country            Poland       Lebanon          France  \
# Continent          Europe          Asia          Europe
# Region     Eastern Europe  Western Asia  Western Europe
#
# ...

# %%
list80s = list(map(str, np.arange(1980,1990)))
list90s = list(map(str, np.arange(1990,2000)))
list00s = list(map(str, np.arange(2000,2010)))

df80 = df_top155.loc[list80s, :].sum().to_frame(name='80s')
df90 = df_top155.loc[list90s, :].sum().to_frame(name='90s')
df00 = df_top155.loc[list00s, :].sum().to_frame(name='00s')

new_df = pd.concat([(df_top15['Total']),df80, df90, df00], axis=1).astype('int64')
new_df
# Out:
#                                                      Total     80s     90s  \
# Country
# India                                               691904   82154  180395
# China                                               659962   32003  161528
# United Kingdom of Great Britain and Northern Ir...  551500  179171  261966
# Philippines                                         511391   60764  138482
# Pakistan                                            241600   10591   65302
# United States of America                            241122   76824   56915
# Iran (Islamic Republic of)                          175923   21477   54871
# Sri Lanka                                           148358   14796   70421
# Republic of Korea                                   142581   16259   38189
# Poland                                              139241   57602   64864
# Lebanon                                             115359   24918   49245
# ...

# %%
new_df.describe()
# Out:
#                Total            80s            90s            00s
# count      15.000000      15.000000      15.000000      15.000000
# mean   268346.266667   44418.333333   85594.666667   97471.533333
# std    217736.174584   44190.676455   68237.560246  100583.204205
# min     93585.000000    7613.000000   30028.000000   13629.000000
# 25%    112225.000000   16698.000000   39259.000000   36101.500000
# 50%    148358.000000   30638.000000   56915.000000   65794.000000
# 75%    376495.500000   59183.000000  104451.500000  105505.500000
# max    691904.000000  179171.000000  261966.000000  340385.000000

# %%
new_df.loc[:,['80s', '90s', '00s']].plot(kind='box', figsize=(15,6), ylim=(0, 185000))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plot

# %%
# 1. 1980 columns total
# 2. index moved as a new columnn  (reset_index)
# 3. astype int64 cinverted
# 4. change column names

df_sil = pd.DataFrame(df[years].sum(axis=0)).reset_index().astype('int64')
df_sil.columns = ['year', 'total']
df_sil.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
# we can use the sum() method to get the total population per year
df_tot = pd.DataFrame(df[years].sum(axis=0))

# change the years to type int (useful for regression later on)
df_tot.index = map(int, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace = True)

# rename columns
df_tot.columns = ['year', 'total']

# view the final dataframe
df_tot.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue');

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_tot.plot(kind='bar', x='year', y='total', color='darkblue');

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %% [markdown]
# ## Scatter Plot Regression

# %%
x = df_tot['year']
y = df_tot['total']
fit = np.polyfit(x, y, deg=1)

fit
# Out:
# array([ 5.56709228e+03, -1.09261952e+07])

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

# plot line of best fit
plt.plot(x, fit[0] * x + fit[1], color='red') # recall that x is the Years
plt.annotate('y={0:.0f} x + ({1:.0f})'.format(fit[0], fit[1]), xy=(2000, 150000))

plt.show()

# print out the line of best fit
'No. Immigrants = {0:.0f} * Year + {1:.0f}'.format(fit[0], fit[1])
# Out:
# 'No. Immigrants = 5567 * Year + -10926195'

# %% [markdown]
# 'No. Immigrants = 5567 * Year + -10926195'
#
# <Figure size 1000x600 with 0 Axes>
#
# Using the equation of line of best fit, we can estimate the number of immigrants in 2015:
#
# No. Immigrants = 5567 * Year - 10926195
# No. Immigrants = 5567 * 2015 - 10926195
# No. Immigrants = 291,310
#
# When compared to the actual from Citizenship and Immigration Canada's (CIC) 2016 Annual Report, we see that Canada accepted 271,845 immigrants in 2015. Our estimated value of 291,310 is within 7% of the actual number, which is pretty good considering our original data came from United Nations (and might differ slightly from CIC data).
#
# As a side note, we can observe that immigration took a dip around 1993 - 1997. Further analysis into the topic revealed that in 1993 Canada introcuded Bill C-86 which introduced revisions to the refugee determination system, mostly restrictive. Further amendments to the Immigration Regulations cancelled the sponsorship required for "assisted relatives" and reduced the points awarded to them, making it more difficult for family members (other than nuclear family) to immigrate to Canada. These restrictive measures had a direct impact on the immigration numbers for the next several years.

# %% [markdown]
# Question: Create a scatter plot of the total immigration from Denmark, Norway, and Sweden to Canada from 1980 to 2013?

# %%
df_total = df.loc[['Denmark', 'Norway', 'Sweden'], years].sum(axis=0).reset_index()
df_total.columns = ['year', 'total']
df_total.year = df_total.year.astype('int64')
df_total.head()
# Out:
#    year  total
# 0  1980    669
# 1  1981    678
# 2  1982    627
# 3  1983    333
# 4  1984    252

# %%
df_total.plot(kind='scatter', x='year', y='total', figsize=(15, 6));

# %%
# IBM Solution

#The correct answer is:  

# create df_countries dataframe
df_countries = df_can.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()

# create df_total by summing across three countries for each year
df_total = pd.DataFrame(df_countries.sum(axis=1))

# reset index in place
df_total.reset_index(inplace=True)

# rename columns
df_total.columns = ['year', 'total']

# change column year from string to int to create scatter plot
df_total['year'] = df_total['year'].astype(int)

# show resulting dataframe
df_total.head()

# %% [markdown]
# # Buble Plots

# %% [markdown]
# A bubble plot is a variation of the scatter plot that displays three dimensions of data (x, y, z).
# The data points are replaced with bubbles, and the size of the bubble is determined by the third variable z,also known as the weight. In maplotlib, we can pass in an array or scalar to the parameter s to plot(), that contains the weight of each point.

# %%
# transposed dataframe
df_can_t = df[years].transpose()

# cast the Years (the index) to type int
df_can_t.index = map(int, df_can_t.index)

# let's label the index. This will automatically be the column name when we reset the index
df_can_t.index.name = 'Year'

# reset index to bring the Year in as a column
df_can_t.reset_index(inplace=True)

# view the changes
df_can_t.head()
# Out:
# Country  Year  Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 0        1980           16        1       80               0        0       1
# 1        1981           39        0       67               1        0       3
# 2        1982           39        0       71               0        0       6
# 3        1983           47        0       69               0        0       6
# 4        1984           71        0       63               0        0       4
#
# Country  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 0                          0        368        0        702      234
# 1                          0        426        0        639      238
# 2                          0        626        0        484      201
# 3                          0        241        0        317      117
# 4                         42        237        0        317      127
#
# Country  Azerbaijan  Bahamas  Bahrain  Bangladesh  Barbados  Belarus  Belgium  \
# ...

# %%
# normalize Brazil data
norm_brazil = (df_can_t['Brazil'] - df_can_t['Brazil'].min()) / (df_can_t['Brazil'].max() - df_can_t['Brazil'].min())

# normalize Argentina data
norm_argentina = (df_can_t['Argentina'] - df_can_t['Argentina'].min()) / (df_can_t['Argentina'].max() - df_can_t['Argentina'].min())

# %% [markdown]
# Step 3: Plot the data.
#
#     To plot two different scatter plots in one plot, we can include the axes one plot into the other by passing it via the ax parameter.
#     We will also pass in the weights using the s parameter. Given that the normalized weights are between 0-1, they won't be visible on the plot. Therefore, we will:
#         multiply weights by 2000 to scale it up on the graph, and,
#         add 10 to compensate for the min value (which has a 0 weight and therefore scale with ×2000
#
# ).

# %%
# Brazil
ax0 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Brazil',
                    figsize=(14, 8),
                    alpha=0.5,  # transparency
                    color='green',
                    s=norm_brazil * 2000 + 10,  # pass in weights 
                    xlim=(1975, 2015)
                    )

# Argentina
ax1 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Argentina',
                    alpha=0.5,
                    color="blue",
                    s=norm_argentina * 2000 + 10,
                    ax=ax0
                    )

ax0.set_ylabel('Number of Immigrants')
ax0.set_title('Immigration from Brazil and Argentina from 1980 to 2013')
ax0.legend(['Brazil', 'Argentina'], loc='upper left', fontsize='x-large')

# %% [markdown]
# The size of the bubble corresponds to the magnitude of immigrating population for that year, compared to the 1980 - 2013 data. The larger the bubble is, the more immigrants are in that year.
#
# ​
#
# From the plot above, we can see a corresponding increase in immigration from Argentina during the 1998 - 2002 great depression. We can also observe a similar spike around 1985 to 1993. In fact, Argentina had suffered a great depression from 1974 to 1990, just before the onset of 1998 - 2002 great depression.
#
# ​
#
# On a similar note, Brazil suffered the *Samba Effect* where the Brazilian real (currency) dropped nearly 35% in 1999. There was a fear of a South American financial crisis as many South American countries were heavily dependent on industrial exports from Brazil. The Brazilian government subsequently adopted an austerity program, and the economy slowly recovered over the years, culminating in a surge in 2010. The immigration data reflect these events.

# %%
# Brazil
ax0 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Brazil',
                    figsize=(14, 8),
                    alpha=0.5,  # transparency
                    color='green',
                    s=norm_brazil * 2000 + 1000,  # pass in weights 
                    xlim=(1975, 2015)
                    )

# Argentina
ax1 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Argentina',
                    alpha=0.5,
                    color="blue",
                    s=norm_argentina * 2000 + 10 ,
                    ax=ax0
                    )

ax0.set_ylabel('Number of Immigrants')
ax0.set_title('Immigration from Brazil and Argentina from 1980 to 2013')
ax0.legend(['Brazil', 'Argentina'], loc='upper left', fontsize='x-large')

# %% [markdown]
# # Waffle Charts

# %%
from PIL import Image

# %%
df_dsn = df.loc[['Denmark', 'Norway', 'Sweden'], :]
df_dsn
# Out:
#         Continent           Region            DevName  1980  1981  1982  1983  \
# Country
# Denmark    Europe  Northern Europe  Developed regions   272   293   299   106
# Norway     Europe  Northern Europe  Developed regions   116    77   106    51
# Sweden     Europe  Northern Europe  Developed regions   281   308   222   176
#
#          1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  \
# Country
# Denmark    93    73    93   109   129   129   118   111   158   186    93
# Norway     31    54    56    80    73    76    83   103    74    92    60
# Sweden    128   158   187   198   171   182   130   167   179   203   192
#
#          1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  \
# Country
# Denmark   111    70    83    63    81    93    81    70    89    89    62
# Norway     65    70   104    31    36    56    78    74    77    73    57
# Sweden    176   161   151   123   170   138   184   149   161   129   205
#
# ...

# %%
# Step 1. The first step into creating a waffle chart is determing the proportion of each category with respect to the total.

# compute the proportion of each category with respect to the total
total_values = df_dsn['Total'].sum()
category_proportions = df_dsn['Total'] / total_values

# print out proportions
pd.DataFrame({'Category_Proportion' :  category_proportions})
# Out:
#          Category_Proportion
# Country
# Denmark             0.322557
# Norway              0.192409
# Sweden              0.485034

# %%
# Step 2. The second step is defining the overall size of the waffle chart.

width = 40 # width of chart
height = 10 # height of chart

total_num_tiles = width * height # total number of tiles

print(f'Total number of tiles is {total_num_tiles}.')
# Out:
# Total number of tiles is 400.

# %%
# compute the number of tiles for each category
tiles_per_category = (category_proportions * total_num_tiles).round().astype(int)

# print out number of tiles per category
pd.DataFrame({"Number of tiles": tiles_per_category})
# Out:
#          Number of tiles
# Country
# Denmark              129
# Norway                77
# Sweden               194

# %% [markdown]
# # Word Clouds

# %% [markdown]
# # Regression Plots

# %%
# we can use the sum() method to get the total population per year
df_tot = pd.DataFrame(df[years].sum(axis=0))

# change the years to type float (useful for regression later on)
df_tot.index = map(float, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace=True)

# rename columns
df_tot.columns = ['year', 'total']

# view the final dataframe
df_tot.head()
# Out:
#      year   total
# 0  1980.0   99137
# 1  1981.0  110563
# 2  1982.0  104271
# 3  1983.0   75550
# 4  1984.0   73417

# %%
sns.regplot(x='year', y='total', data=df_tot);

# %%
plt.figure(figsize=(15, 10))

# Fonts
sns.set(font_scale=1.5)
# Background Style
sns.set_style('whitegrid')

# scatter_kws = scatter size
# marker = scatter style
ax = sns.regplot(x='year', y='total', data=df_tot, color='green', marker='+', scatter_kws={'s': 200})
ax.set(xlabel='Year', ylabel='Total Immigration')
ax.set_title('Total Immigration to Canada from 1980 - 2013')
plt.show()

# %% [markdown]
# # Geospatial Data

# %%
#!pip install folium
import folium
# Out:
# ...
#      |████████████████████████████████| 95 kB 1.7 MB/s eta 0:00:01
# ...

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# define the world map centered around Canada with a low zoom level
world_map = folium.Map(location=[56.130, -106.35], zoom_start=4)

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Question: Create a map of Mexico with a zoom level of 4.

#The correct answer is:

#define Mexico's geolocation coordinates
mexico_latitude = 23.6345 
mexico_longitude = -102.5528

# define the world map centered around Canada with a higher zoom level
mexico_map = folium.Map(location=[mexico_latitude, mexico_longitude], zoom_start=4)

# display world map
mexico_map

# %%
# define the world map centered around Canada with a higher zoom level
world_map = folium.Map(location=[56.130, -106.35], zoom_start=8)

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# ------       Stamen Terrain
# create a Stamen Toner map of the world centered around Canada
world_map = folium.Map(location=[56.130, -106.35], zoom_start=4, tiles='Stamen Terrain')

# display map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import piplite

await piplite.install(['openpyxl==3.0.9', 'folium'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [130], in <cell line: 1>()
# ----> 1 import piplite
#       3 await piplite.install(['openpyxl==3.0.9', 'folium'])
#
# ModuleNotFoundError: No module named 'piplite'

# %%
# !pip install js
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Police_Department_Incidents_-_Previous_Year__2016_.csv'
resp = await fetch(URL)
text = io.BytesIO((await resp.arrayBuffer()).to_py())

df_incidents =  pd.read_csv(text)

print('Dataset downloaded and read into a pandas dataframe!')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [129], in <cell line: 1>()
# ----> 1 from js import fetch
#       2 import io
#       4 URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Police_Department_Incidents_-_Previous_Year__2016_.csv'
#
# ModuleNotFoundError: No module named 'js'

# %%
# Load data
# Map of Police Department Incident Reports: 2018 to Present
df_incidents = pd.read_csv('Police_Department_Incident_Reports__2018_to_Present.csv')
df_incidents.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2019/03/05 09:00:00 PM    2019/03/05         21:00           2019
# 1  2018/12/22 12:00:00 PM    2018/12/22         12:00           2018
# 2  2018/08/24 05:30:00 PM    2018/08/24         17:30           2018
# 3  2018/10/20 03:10:00 PM    2018/10/20         15:10           2018
# 4  2019/06/05 12:36:00 AM    2019/06/05         00:36           2019
#
#   Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 0              Tuesday  2019/03/07 12:54:00 PM  77808706372       778087
# 1             Saturday  2018/12/26 02:29:00 PM  75246907023       752469
# 2               Friday  2018/08/24 07:35:00 PM  70675306243       706753
# 3             Saturday  2018/10/20 03:10:00 PM  72826462071       728264
# 4            Wednesday  2019/06/05 12:37:00 AM  80823030140       808230
#
#    Incident Number   CAD Number Report Type Code Report Type Description  \
# ...

# %%
df.to_csv('/Users/macbook/Desktop/projects/df_canada.csv')

# %% [markdown]
# So each row consists of 13 features:
#
# > 1.  **IncidntNum**: Incident Number
# > 2.  **Category**: Category of crime or incident
# > 3.  **Descript**: Description of the crime or incident
# > 4.  **DayOfWeek**: The day of week on which the incident occurred
# > 5.  **Date**: The Date on which the incident occurred
# > 6.  **Time**: The time of day on which the incident occurred
# > 7.  **PdDistrict**: The police department district
# > 8.  **Resolution**: The resolution of the crime in terms whether the perpetrator was arrested or not
# > 9.  **Address**: The closest address to where the incident took place
# > 10. **X**: The longitude value of the crime location
# > 11. **Y**: The latitude value of the crime location
# > 12. **Location**: A tuple of the latitude and the longitude values
# > 13. **PdId**: The police department ID

# %%
# get the first 100 crimes in the df_incidents dataframe
limit = 100
df_incidents = df_incidents.iloc[0:100, : ]
df_incidents.shape
# Out:
# (100, 34)

# %%
# save data
df_incidents.to_csv('df_incidents_100')

# %%
# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42

# %%
# create map and display it 
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# display the map of San Francisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Location can not be NAN
df_incidents.loc[ :, ['Latitude', 'Longitude']].isna().sum()
# Out:
# Latitude     8
# Longitude    8
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
df_incidents.dropna(axis=0, subset=['Latitude', 'Longitude'], inplace=True)

# %%
df_incidents.loc[ :, ['Latitude', 'Longitude']].isna().sum()
# Out:
# Latitude     0
# Longitude    0
# dtype: int64

# %%
df_incidents.shape
# Out:
# (92, 34)

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(df_incidents.Latitude, df_incidents.Longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat,lng],
            radius=5,
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
    
# add incidents to map
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(df_incidents.Latitude, df_incidents.Longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat,lng],
            radius=5,
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(df_incidents.Latitude)
longitudes = list(df_incidents.Longitude)
labels = list(df_incidents['Incident Category'])    

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat,lng], popup=label).add_to(sanfran_map)
    
# add incidents to map
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# create map and display it
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, label in zip(df_incidents.Latitude, df_incidents.Longitude, df_incidents['Incident Category']):
    folium.features.CircleMarker(
        [lat,lng],
        radius=5,
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(sanfran_map)
    
# add incidents to map
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
sanfran_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(sanfran_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_incidents.Latitude, df_incidents.Longitude, df_incidents['Incident Category']):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# display map
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
