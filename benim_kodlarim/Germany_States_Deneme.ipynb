# %%
# Faydali linkler 

====> postakodu ile nufus yogunlugu haritasi almanya
https://juanitorduz.github.io/germany_plots/  

===> plotly.express.choropleth DOC
https://plotly.github.io/plotly.py-docs/generated/plotly.express.choropleth.html

===> How to create outstanding custom choropleth maps with Plotly and Dash 🌎
https://towardsdatascience.com/how-to-create-outstanding-custom-choropleth-maps-with-plotly-and-dash-49ac918a5f05


# https://chart-studio.plotly.com/~empet/15047/germany-states-mapbox-choropleth-from-a-shapefile/#data

# %%
# Environment used: dash1_8_0_env
import pandas as pd     #(version 1.0.0)
import numpy as np
import json

import plotly           #(version 4.5.0)
import plotly.express as px

import dash             #(version 1.8.0)
from dash import dcc, html
from dash.dependencies import Input, Output, State
from dash.exceptions import PreventUpdate

# %%
df = px.data.gapminder()
df.head()
df_germany = df.query('country=="Germany"')
df_germany
# Out:
#      country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 564  Germany    Europe  1952   67.500  69145952   7144.114393       DEU
# 565  Germany    Europe  1957   69.100  71019069  10187.826650       DEU
# 566  Germany    Europe  1962   70.300  73739117  12902.462910       DEU
# 567  Germany    Europe  1967   70.800  76368453  14745.625610       DEU
# 568  Germany    Europe  1972   71.000  78717088  18016.180270       DEU
# 569  Germany    Europe  1977   72.500  78160773  20512.921230       DEU
# 570  Germany    Europe  1982   73.800  78335266  22031.532740       DEU
# 571  Germany    Europe  1987   74.847  77718298  24639.185660       DEU
# 572  Germany    Europe  1992   76.070  80597764  26505.303170       DEU
# 573  Germany    Europe  1997   77.340  82011073  27788.884160       DEU
# 574  Germany    Europe  2002   78.670  82350671  30035.801980       DEU
# 575  Germany    Europe  2007   79.406  82400996  32170.374420       DEU
#
#      iso_num
# 564      276
# ...

# %%
fig = px.choropleth(df_germany, locations=df_germany.iso_alpha,
                            color="lifeExp",
                            hover_name="country",
                            projection='natural earth',
                            scope='europe',
                            title='Life Expectancy by Year',
                            color_continuous_scale=px.colors.sequential.Plasma)

fig.update_layout(title=dict(font=dict(size=28),x=0.5,xanchor='center'),
                          margin=dict(l=60, r=60, t=50, b=50))

# %%
df_germany[['lat', 'lon']] = [52.520008, 13.404954]
df_germany
# Out:
# /var/folders/ht/tcz99qld7qz6stv5g043rfyc0000gn/T/ipykernel_62055/4104095220.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/ht/tcz99qld7qz6stv5g043rfyc0000gn/T/ipykernel_62055/4104095220.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 564  Germany    Europe  1952   67.500  69145952   7144.114393       DEU
# 565  Germany    Europe  1957   69.100  71019069  10187.826650       DEU
# ...

# %%
fig = px.choropleth(df_germany, 
                    lat = 'lat',
                    lon = 'lon',
                    color="lifeExp",
                    hover_name="country",
                    projection='natural earth',
                    scope='europe',
                    title='Life Expectancy by Year',
                    color_continuous_scale=px.colors.sequential.Plasma)

fig.update_layout(title=dict(font=dict(size=28),x=0a.5,xanchor='center'),
                          margin=dict(l=60, r=60, t=50, b=50))
#fig.update_traces(locationmode='country names', selector=dict(type='scattergeo'))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [133], in <cell line: 1>()
# ----> 1 fig = px.choropleth(df_germany,
#       2                     lat = 'lat',
#       3                     lon = 'lon',
#       4                     color="lifeExp",
#       5                     hover_name="country",
#       6                     projection='natural earth',
#       7                     scope='europe',
#       8                     title='Life Expectancy by Year',
#       9                     color_continuous_scale=px.colors.sequential.Plasma)
#      11 fig.update_layout(title=dict(font=dict(size=28),x=0.5,xanchor='center'),
#      12                           margin=dict(l=60, r=60, t=50, b=50))
#      13 #fig.update_traces(locationmode='country names', selector=dict(type='scattergeo'))
#
# ...

# %%
lat = 52.520008,
lon = 13.404954

# %%
import ssl

try:
   _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    # Legacy Python that doesn't verify HTTPS certificates by default
    pass
else:
    # Handle target environment that doesn't support HTTPS verification
    ssl._create_default_https_context = _create_unverified_https_context

    
#conda install plotly conda install geopandas
#conda install -c conda-forge plotly
#pip conda install -c conda-forge geopandas

# %%
import sys
# !{sys.executable} -m pip install plotly

# %%
pwd
# Out:
# '/Users/macbook/Desktop/projects/Github_Repositories/IBM5 - Data Visualization with Python/benim_kodlarim'

# %%
# Loading geojson from (DATA_PATH depending on your local settings)
DATA_PATH = '/Users/macbook/Desktop/projects/Github_Repositories/IBM5 - Data Visualization with Python/benim_kodlarim/'
world_path = DATA_PATH + 'custom.geo.json'
with open(world_path) as f:
    geo_world = json.load(f)

    
    
geo_world
# # Instanciating necessary lists
# found = []
# missing = []
# countries_geo = []

# # For simpler acces, setting "zone" as index in a temporary dataFrame
# tmp = df.set_index('zone')

# # Looping over the custom GeoJSON file
# for country in geo_world['features']:
    
#     # Country name detection
#     country_name = country['properties']['name'] 
    
#     # Checking if that country is in the dataset
#     if country_name in tmp.index:
        
#         # Adding country to our "Matched/found" countries
#         found.append(country_name)
        
#         # Getting information from both GeoJSON file and dataFrame
#         geometry = country['geometry']
        
#         # Adding 'id' information for further match between map and data 
#         countries_geo.append({
#             'type': 'Feature',
#             'geometry': geometry,
#             'id':country_name
#         })
        
#     # Else, adding the country to the missing countries
#     else:
#         missing.append(country_name)

# # Displaying metrics
# print(f'Countries found    : {len(found)}')
# print(f'Countries not found: {len(missing)}')
# geo_world_ok = {'type': 'FeatureCollection', 'features': countries_geo}
# Out:
# {'type': 'FeatureCollection', 'features': []}

# %% [markdown]
# # Json Countries

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

counties["features"][100]
# Out:
# {'type': 'Feature',
#  'properties': {'GEO_ID': '0500000US16067',
#   'STATE': '16',
#   'COUNTY': '067',
#   'NAME': 'Minidoka',
#   'LSAD': 'County',
#   'CENSUSAREA': 757.591},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-113.931799, 42.535275],
#     [-113.932904, 42.765032],
#     [-113.763862, 42.764508],
#     [-113.713928, 42.849733],
#     [-113.714701, 43.20003],
#     [-113.413693, 43.199785],
#     [-113.413026, 42.84925],
#     [-113.472155, 42.849218],
#     [-113.472177, 42.669251],
#     [-113.557609, 42.656416],
#     [-113.655338, 42.535663],
#     [-113.779811, 42.55687],
#     [-113.931799, 42.535275]]]},
#  'id': '16067'}

# %%
counties["features"][0].keys()
# Out:
# dict_keys(['type', 'properties', 'geometry', 'id'])

# %%
counties["features"][0]['properties']['NAME']
# Out:
# 'Autauga'

# %%
counties["features"][-120]
# Out:
# {'type': 'Feature',
#  'properties': {'GEO_ID': '0500000US51735',
#   'STATE': '51',
#   'COUNTY': '735',
#   'NAME': 'Poquoson',
#   'LSAD': 'city',
#   'CENSUSAREA': 15.317},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-76.287236, 37.117453],
#     [-76.381383, 37.111939],
#     [-76.387733, 37.109181],
#     [-76.384265, 37.107383],
#     [-76.384553, 37.105167],
#     [-76.393795, 37.108397],
#     [-76.39447, 37.106248],
#     [-76.413638, 37.137968],
#     [-76.397883, 37.164415],
#     [-76.399659, 37.160272],
#     [-76.394756, 37.157568],
#     [-76.381379, 37.155711],
#     [-76.375255, 37.16084],
#     [-76.35969, 37.16858],
#     [-76.348658, 37.170655],
#     [-76.343234, 37.166207],
#     [-76.344898, 37.164479],
#     [-76.34405, 37.160367],
#     [-76.340129, 37.151823],
#     [-76.334017, 37.144223],
#     [-76.330481, 37.141727],
#     [-76.324353, 37.142895],
#     [-76.311088, 37.138495],
#     [-76.292344, 37.126615],
# ...

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/isellsoap/deutschlandGeoJSON/main/1_deutschland/1_sehr_hoch.geo.json') as response:
    germany = json.load(response)

germany["features"][0]
# Out:
# {'type': 'Feature',
#  'id': 0,
#  'properties': {'ID_0': 86,
#   'ISO': 'DEU',
#   'NAME_ENGLI': 'Germany',
#   'NAME_ISO': 'GERMANY',
#   'NAME_FAO': 'Germany',
#   'NAME_LOCAL': 'Deutschland',
#   'NAME_OBSOL': None,
#   'NAME_VARIA': 'Germany',
#   'NAME_NONLA': None,
#   'NAME_FRENC': 'Allemagne',
#   'NAME_SPANI': 'Alemania',
#   'NAME_RUSSI': '????????',
#   'NAME_ARABI': '???????',
#   'NAME_CHINE': '??',
#   'WASPARTOF': None,
#   'CONTAINS': 'East Germany|West Germany|DDR',
#   'SOVEREIGN': 'Germany',
#   'ISO2': 'DE',
#   'WWW': None,
#   'FIPS': 'GM',
#   'ISON': 276.0,
#   'VALIDFR': 'Unknown',
#   'VALIDTO': 'Present',
#   'EUmember': 1.0},
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[8.708373069763297, 47.71555709838867],
#      [8.709177970886287, 47.71345901489258],
#      [8.710095405578954, 47.71168518066429],
#      [8.710541725158635, 47.70994949340832],
#      [8.710783958435286, 47.70932006835932],
# ...

# %%
df = pd.read_csv('de.csv')
df.head()
# Out:
#         city      lat      lng  country iso2              admin_name  capital  \
# 0     Berlin  52.5167  13.3833  Germany   DE                  Berlin  primary
# 1    Hamburg  53.5500  10.0000  Germany   DE                 Hamburg    admin
# 2     Munich  48.1372  11.5755  Germany   DE                 Bavaria    admin
# 3    Cologne  50.9422   6.9578  Germany   DE  North Rhine-Westphalia      NaN
# 4  Frankfurt  50.1136   8.6797  Germany   DE                   Hesse    minor
#
#    population  population_proper
# 0   3644826.0          3644826.0
# 1   1841179.0          1841179.0
# 2   1471508.0          1471508.0
# 3   1085664.0          1085664.0
# 4    753056.0           753056.0

# %%
fig = px.choropleth_mapbox(df, geojson=germany, locations='city', color='city',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           mapbox_style="carto-positron",
                           zoom=3, center = {"lat": 50.1136, "lon": 8.6797},
                           opacity=0.5,
                           labels={'unemp':'unemployment rate'}
                          )
#fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 fig = px.choropleth_mapbox(df, geojson=germany, locations='city', color='city',
#       2                            color_continuous_scale="Viridis",
#       3                            range_color=(0, 12),
#       4                            mapbox_style="carto-positron",
#       5                            zoom=3, center = {"lat": 50.1136, "lon": 8.6797},
#       6                            opacity=0.5,
#       7                            labels={'unemp':'unemployment rate'}
#       8                           )
#       9 #fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
#      10 fig.show()
#
# ...

# %%
df.shape
# Out:
# (603, 9)

# %%
# USA Sample

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

import pandas as pd
dff = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv",
                   dtype={"fips": str})

dff.head()
# import plotly.express as px

# fig = px.choropleth_mapbox(dff, geojson=counties, locations='fips', color='unemp',
#                            color_continuous_scale="Viridis",
#                            range_color=(0, 12),
#                            mapbox_style="carto-positron",
#                            zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
#                            opacity=0.5,
#                            labels={'unemp':'unemployment rate'}
#                           )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()
# Out:
#     fips  unemp
# 0  01001    5.3
# 1  01003    5.4
# 2  01005    8.6
# 3  01007    6.6
# 4  01009    5.5
