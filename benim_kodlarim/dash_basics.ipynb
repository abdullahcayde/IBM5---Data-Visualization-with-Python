# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore')

#Butun kolon ve satirlari gormek icin
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#virgulden sonra gösterilecek olan sayı 2 basamak olarak ayarlanıyor.
#pd.set_option('display.float_format', lambda x: '%.2f' % x)
#pd.options.display.float_format = '{:,.2f}'.format

import dash
from dash import html 
from dash import dcc

# Import required libraries
import pandas as pd
import plotly.express as px
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
airline_data = pd.read_csv('df_airline_3000.csv')
airline_data.drop('Unnamed: 0', axis=1, inplace=True)
airline_data.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  1998        1      1           2          5  1998-01-02                NW
# 1  2009        2      5          28          4  2009-05-28                FL
# 2  2013        2      6          29          6  2013-06-29                MQ
# 3  2010        3      8          31          2  2010-08-31                DL
# 4  2006        1      1          15          7  2006-01-15                US
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  \
# 0                     19386                          NW      N297US
# 1                     20437                          FL      N946AT
# 2                     20398                          MQ      N665MQ
# 3                     19790                          DL      N6705Y
# 4                     20355                          US      N504AU
#
#    Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                              675            13487             1348701
# 1                              671            13342             1334202
# 2                             3297            11921             1192102
# 3                             1806            12892             1289201
# 4                              465            11618             1161801
#
#    OriginCityMarketID Origin      OriginCityName OriginState  OriginStateFips  \
# 0               31650    MSP     Minneapolis, MN          MN               27
# 1               33342    MKE       Milwaukee, WI          WI               55
# 2               31921    GJT  Grand Junction, CO          CO                8
# 3               32575    LAX     Los Angeles, CA          CA                6
# 4               31703    EWR          Newark, NJ          NJ               34
#
#   OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 0       Minnesota         63          14869           1486902
# 1       Wisconsin         45          13204           1320401
# 2        Colorado         82          11298           1129803
# 3      California         91          11433           1143301
# 4      New Jersey         21          11057           1105702
#
#    DestCityMarketID Dest           DestCityName DestState  DestStateFips  \
# 0             34614  SLC     Salt Lake City, UT        UT           49.0
# 1             31454  MCO            Orlando, FL        FL           12.0
# 2             30194  DFW  Dallas/Fort Worth, TX        TX           48.0
# 3             31295  DTW            Detroit, MI        MI           26.0
# 4             31057  CLT          Charlotte, NC        NC           37.0
#
#     DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  DepDelayMinutes  \
# 0            Utah       87        1640   1659.0      19.0             19.0
# 1         Florida       33        1204   1202.0      -2.0              0.0
# 2           Texas       74        1630   1644.0      14.0             14.0
# 3        Michigan       43        1305   1305.0       0.0              0.0
# 4  North Carolina       36        1820   1911.0      51.0             51.0
#
#    DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  \
# 0       1.0                   1.0  1600-1659     24.0     1723.0    1856.0
# 1       0.0                  -1.0  1200-1259     10.0     1212.0    1533.0
# 2       0.0                   0.0  1600-1659      9.0     1653.0    1936.0
# 3       0.0                   0.0  1300-1359     23.0     1328.0    2008.0
# 4       1.0                   3.0  1800-1859     19.0     1930.0    2050.0
#
#    TaxiIn  CRSArrTime  ArrTime  ArrDelay  ArrDelayMinutes  ArrDel15  \
# 0     3.0        1836   1859.0      23.0             23.0       1.0
# 1     8.0        1541   1541.0       0.0              0.0       0.0
# 2     6.0        1945   1942.0      -3.0              0.0       0.0
# 3     7.0        2035   2015.0     -20.0              0.0       0.0
# 4     8.0        2026   2058.0      32.0             32.0       1.0
#
#    ArrivalDelayGroups ArrTimeBlk  Cancelled CancellationCode  Diverted  \
# 0                 1.0  1800-1859        0.0              NaN       0.0
# 1                 0.0  1500-1559        0.0              NaN       0.0
# 2                -1.0  1900-1959        0.0              NaN       0.0
# 3                -2.0  2000-2059        0.0              NaN       0.0
# 4                 2.0  2000-2059        0.0              NaN       0.0
#
#    CRSElapsedTime  ActualElapsedTime  AirTime  Flights  Distance  \
# 0           176.0              180.0    153.0      1.0     991.0
# 1           157.0              159.0    141.0      1.0    1066.0
# 2           135.0              118.0    103.0      1.0     773.0
# 3           270.0              250.0    220.0      1.0    1979.0
# 4           126.0              107.0     80.0      1.0     529.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              4           NaN           NaN       NaN            NaN
# 1              5           NaN           NaN       NaN            NaN
# 2              4           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              3           0.0           0.0       0.0            0.0
#
#    LateAircraftDelay  FirstDepTime  TotalAddGTime  LongestAddGTime  \
# 0                NaN           NaN            NaN              NaN
# 1                NaN           NaN            NaN              NaN
# 2                NaN           NaN            NaN              NaN
# 3                NaN           NaN            NaN              NaN
# 4               32.0           NaN            NaN              NaN
#
#    DivAirportLandings  DivReachedDest  DivActualElapsedTime  DivArrDelay  \
# 0                 NaN             NaN                   NaN          NaN
# 1                 0.0             NaN                   NaN          NaN
# 2                 0.0             NaN                   NaN          NaN
# 3                 0.0             NaN                   NaN          NaN
# 4                 NaN             NaN                   NaN          NaN
#
#    DivDistance Div1Airport  Div1AirportID  Div1AirportSeqID  Div1WheelsOn  \
# 0          NaN         NaN            NaN               NaN           NaN
# 1          NaN         NaN            NaN               NaN           NaN
# 2          NaN         NaN            NaN               NaN           NaN
# 3          NaN         NaN            NaN               NaN           NaN
# 4          NaN         NaN            NaN               NaN           NaN
#
#    Div1TotalGTime  Div1LongestGTime  Div1WheelsOff Div1TailNum  Div2Airport  \
# 0             NaN               NaN            NaN         NaN          NaN
# 1             NaN               NaN            NaN         NaN          NaN
# 2             NaN               NaN            NaN         NaN          NaN
# 3             NaN               NaN            NaN         NaN          NaN
# 4             NaN               NaN            NaN         NaN          NaN
#
#    Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 0            NaN               NaN           NaN             NaN
# 1            NaN               NaN           NaN             NaN
# 2            NaN               NaN           NaN             NaN
# 3            NaN               NaN           NaN             NaN
# 4            NaN               NaN           NaN             NaN
#
#    Div2LongestGTime  Div2WheelsOff  Div2TailNum  Div3Airport  Div3AirportID  \
# 0               NaN            NaN          NaN          NaN            NaN
# 1               NaN            NaN          NaN          NaN            NaN
# 2               NaN            NaN          NaN          NaN            NaN
# 3               NaN            NaN          NaN          NaN            NaN
# 4               NaN            NaN          NaN          NaN            NaN
#
#    Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  Div3LongestGTime  \
# 0               NaN           NaN             NaN               NaN
# 1               NaN           NaN             NaN               NaN
# 2               NaN           NaN             NaN               NaN
# 3               NaN           NaN             NaN               NaN
# 4               NaN           NaN             NaN               NaN
#
#    Div3WheelsOff  Div3TailNum  Div4Airport  Div4AirportID  Div4AirportSeqID  \
# 0            NaN          NaN          NaN            NaN               NaN
# 1            NaN          NaN          NaN            NaN               NaN
# 2            NaN          NaN          NaN            NaN               NaN
# 3            NaN          NaN          NaN            NaN               NaN
# 4            NaN          NaN          NaN            NaN               NaN
#
#    Div4WheelsOn  Div4TotalGTime  Div4LongestGTime  Div4WheelsOff  Div4TailNum  \
# 0           NaN             NaN               NaN            NaN          NaN
# 1           NaN             NaN               NaN            NaN          NaN
# 2           NaN             NaN               NaN            NaN          NaN
# 3           NaN             NaN               NaN            NaN          NaN
# 4           NaN             NaN               NaN            NaN          NaN
#
#    Div5Airport  Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 0          NaN            NaN               NaN           NaN             NaN
# 1          NaN            NaN               NaN           NaN             NaN
# 2          NaN            NaN               NaN           NaN             NaN
# 3          NaN            NaN               NaN           NaN             NaN
# 4          NaN            NaN               NaN           NaN             NaN
#
#    Div5LongestGTime  Div5WheelsOff  Div5TailNum
# 0               NaN            NaN          NaN
# 1               NaN            NaN          NaN
# 2               NaN            NaN          NaN
# 3               NaN            NaN          NaN
# 4               NaN            NaN          NaN

# %%
# !pip install pandas dash
# !pip install httpx==0.20 dash plotly
print('Succesfull')
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: dash in /opt/anaconda3/lib/python3.9/site-packages (2.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.23.2)
# Requirement already satisfied: Flask>=1.0.4 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==5.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (5.6.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: flask-compress in /opt/anaconda3/lib/python3.9/site-packages (from dash) (1.12)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: brotli in /opt/anaconda3/lib/python3.9/site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: httpx==0.20 in /opt/anaconda3/lib/python3.9/site-packages (0.20.0)
# Requirement already satisfied: dash in /opt/anaconda3/lib/python3.9/site-packages (2.6.1)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.9/site-packages (5.6.0)
# Requirement already satisfied: charset-normalizer in /opt/anaconda3/lib/python3.9/site-packages (from httpx==0.20) (2.0.4)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.9/site-packages (from httpx==0.20) (1.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from httpx==0.20) (2021.10.8)
# Requirement already satisfied: httpcore<0.14.0,>=0.13.3 in /opt/anaconda3/lib/python3.9/site-packages (from httpx==0.20) (0.13.7)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /opt/anaconda3/lib/python3.9/site-packages (from httpx==0.20) (1.5.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (5.0.0)
# Requirement already satisfied: flask-compress in /opt/anaconda3/lib/python3.9/site-packages (from dash) (1.12)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from plotly) (1.16.0)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: anyio==3.* in /opt/anaconda3/lib/python3.9/site-packages (from httpcore<0.14.0,>=0.13.3->httpx==0.20) (3.5.0)
# Requirement already satisfied: h11<0.13,>=0.11 in /opt/anaconda3/lib/python3.9/site-packages (from httpcore<0.14.0,>=0.13.3->httpx==0.20) (0.12.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.9/site-packages (from anyio==3.*->httpcore<0.14.0,>=0.13.3->httpx==0.20) (3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: brotli in /opt/anaconda3/lib/python3.9/site-packages (from flask-compress->dash) (1.0.9)
# Succesfull

# %%
# Randomly sample 500 data points. Setting the random state to be 42 so that we get same result.
data = airline_data.sample(n=500, random_state=42)

# Pie Chart Creation
fig = px.pie(data, values='Flights', names='DistanceGroup', title='Distance group proportion by flights')

# Create a dash application
app = dash.Dash(__name__)

# Get the layout of the application and adjust it.
# Create an outer division using html.Div and add title to the dashboard using html.H1 component
# Add description about the graph using HTML P (paragraph) component
# Finally, add graph component.
app.layout = html.Div(children=[html.H1('Airline Dashboard',
                                        style={'textAlign': 'center', 
                                                'color': '#503D36',
                                                'font-size': 40}),
                                html.P('Proportion of distance group (250 mile distance interval group) by flights.',
                                         style={'textAlign':'center', 'color': '#F57241'}),
                                dcc.Graph(figure=fig),

                    ])

# Run the application                   
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [01/Sep/2022 16:11:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 16:11:53] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Sep/2022 16:11:53] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Sep/2022 16:11:53] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 16:11:53] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 17:01:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 17:01:26] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Sep/2022 17:01:26] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Sep/2022 17:01:26] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 17:01:26] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 17:01:26] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Sep/2022 17:01:26] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
