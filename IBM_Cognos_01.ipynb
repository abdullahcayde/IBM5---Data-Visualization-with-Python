# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
clp = pd.read_csv("CustomerLoyaltyProgram.csv")
df = clp.copy()
df.head()
# Out:
#    Loyalty# First Name Last Name  Customer Name  Country Province or State  \
# 0  837810.0    Abigail     Goris  Abigail Goris   Canada  British Columbia
# 1  707928.0        Ada    Glaude     Ada Glaude  Germany            Bremen
# 2  901442.0        Ada   Staback    Ada Staback   Canada          Manitoba
# 3  237303.0       Adam     Boner     Adam Boner   Canada           Ontario
# 4  348835.0       Adam  Dunnegan  Adam Dunnegan   Canada          Manitoba
#
#            City   Latitude   Longitude Postal code  Gender  \
# 0  Dawson Creek  55.759627 -120.237662     U5I 4F1    male
# 1        Bremen  53.079296    8.801694       28759    male
# 2      Winnipeg  49.895136  -97.138374     R2C 0M5  female
# 3       Sudbury  46.522099  -80.953035     M5V 1G5  female
# 4      Winnipeg  49.895136  -97.138374     R2C 0M5    male
#
#               Education Location Code   Income Marital Status  Order Year  \
# 0              Bachelor         Rural  42142.0         Single      2016.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89950 entries, 0 to 89949
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Loyalty#                 84445 non-null  float64
#  1   First Name               84445 non-null  object
#  2   Last Name                84445 non-null  object
#  3   Customer Name            84445 non-null  object
#  4   Country                  84445 non-null  object
#  5   Province or State        84445 non-null  object
#  6   City                     84445 non-null  object
#  7   Latitude                 84436 non-null  float64
#  8   Longitude                84436 non-null  float64
#  9   Postal code              84445 non-null  object
#  10  Gender                   84445 non-null  object
#  11  Education                84445 non-null  object
#  12  Location Code            84445 non-null  object
#  13  Income                   84445 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Loyalty#', 'First Name', 'Last Name', 'Customer Name', 'Country',
#        'Province or State', 'City', 'Latitude', 'Longitude', 'Postal code',
#        'Gender', 'Education', 'Location Code', 'Income', 'Marital Status',
#        'Order Year', 'Quarter', 'MonthsAsMember', 'LoyaltyStatus',
#        'Product Line', 'Coupon Response', 'Count', 'Quantity Sold',
#        'Unit Sale Price', 'Unit Cost', 'Revenue', 'Customer Lifetime Value',
#        'Loyalty Count'],
#       dtype='object')

# %%
df[['Unit Sale Price', 'Unit Cost', 'Revenue']] = df[['Unit Sale Price', 'Unit Cost', 'Revenue']].apply(lambda x : x.str.replace('$','').str.replace(',','')).astype(float)
df.info()
# Out:
# /var/folders/ht/tcz99qld7qz6stv5g043rfyc0000gn/T/ipykernel_53742/1137212892.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[['Unit Sale Price', 'Unit Cost', 'Revenue']] = df[['Unit Sale Price', 'Unit Cost', 'Revenue']].apply(lambda x : x.str.replace('$','').str.replace(',','')).astype(float)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89950 entries, 0 to 89949
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Loyalty#                 84445 non-null  float64
#  1   First Name               84445 non-null  object
#  2   Last Name                84445 non-null  object
#  3   Customer Name            84445 non-null  object
#  4   Country                  84445 non-null  object
# ...

# %%
df.head()
# Out:
#    Loyalty# First Name Last Name  Customer Name  Country Province or State  \
# 0  837810.0    Abigail     Goris  Abigail Goris   Canada  British Columbia
# 1  707928.0        Ada    Glaude     Ada Glaude  Germany            Bremen
# 2  901442.0        Ada   Staback    Ada Staback   Canada          Manitoba
# 3  237303.0       Adam     Boner     Adam Boner   Canada           Ontario
# 4  348835.0       Adam  Dunnegan  Adam Dunnegan   Canada          Manitoba
#
#            City   Latitude   Longitude Postal code  Gender  \
# 0  Dawson Creek  55.759627 -120.237662     U5I 4F1    male
# 1        Bremen  53.079296    8.801694       28759    male
# 2      Winnipeg  49.895136  -97.138374     R2C 0M5  female
# 3       Sudbury  46.522099  -80.953035     M5V 1G5  female
# 4      Winnipeg  49.895136  -97.138374     R2C 0M5    male
#
#               Education Location Code   Income Marital Status  Order Year  \
# 0              Bachelor         Rural  42142.0         Single      2016.0
# ...

# %%
df.to_csv("clp.csv")

# %%
df = pd.read_csv("clp.csv")
df.head()
# Out:
#    Unnamed: 0  Loyalty# First Name Last Name  Customer Name  Country  \
# 0           0  837810.0    Abigail     Goris  Abigail Goris   Canada
# 1           1  707928.0        Ada    Glaude     Ada Glaude  Germany
# 2           2  901442.0        Ada   Staback    Ada Staback   Canada
# 3           3  237303.0       Adam     Boner     Adam Boner   Canada
# 4           4  348835.0       Adam  Dunnegan  Adam Dunnegan   Canada
#
#   Province or State          City   Latitude   Longitude Postal code  Gender  \
# 0  British Columbia  Dawson Creek  55.759627 -120.237662     U5I 4F1    male
# 1            Bremen        Bremen  53.079296    8.801694       28759    male
# 2          Manitoba      Winnipeg  49.895136  -97.138374     R2C 0M5  female
# 3           Ontario       Sudbury  46.522099  -80.953035     M5V 1G5  female
# 4          Manitoba      Winnipeg  49.895136  -97.138374     R2C 0M5    male
#
#               Education Location Code   Income Marital Status  Order Year  \
# ...
